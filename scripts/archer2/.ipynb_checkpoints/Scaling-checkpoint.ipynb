# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
strong = pd.read_csv('data/strong_scaling_645327.csv')
weak = pd.read_csv('data/weak_scaling_645325.csv')

# %% [markdown]
# # Weak Scaling

# %%
# Calculate performance metrics

weak['speedup'] = weak['']
# Out:
#     n_processes   n_leaves   runtime   encoding_time   sorting_time
# 0             1      32768      3771              13            789
# 1             2      32768      3175              13            853
# 2             4      34224      3312              11            953
# 3             8     262144      5411              11           1220
# 4            16     262144      4745              11           1479
# 5            32     273729      6245              11           2036
# 6            64    2097152      6668              14           3325
# 7           128    2097152      7976              30           5107
# 8           256    2188943     12111              56           9471
# 9           512   16777216     20714              57          17749
# 10         1024   16777216     50657              57          48394
